# %%
import sofar
from pathlib import Path

import matplotlib.pyplot as plt

# %%
path_to_sofa = Path('./outputs_16k/sofa/')
sofa_files = list(path_to_sofa.glob('*.sofa'))
for file in sofa_files:
    print(file)
# Out:
# outputs_16k/sofa/dEchorate_room011111_src8_arr3_mics15-19.sofa
# outputs_16k/sofa/dEchorate_room001000_src1_arr2_mics10-14.sofa
# outputs_16k/sofa/dEchorate_room011100_src3_arr1_mics5-9.sofa
# outputs_16k/sofa/dEchorate_room011111_src5_arr4_mics20-24.sofa
# outputs_16k/sofa/dEchorate_room000010_src5_arr3_mics15-19.sofa
# outputs_16k/sofa/dEchorate_room011110_src4_arr3_mics15-19.sofa
# outputs_16k/sofa/dEchorate_room011111_src8_arr2_mics10-14.sofa
# outputs_16k/sofa/dEchorate_room011110_src3_arr2_mics10-14.sofa
# outputs_16k/sofa/dEchorate_room010000_src3_arr3_mics15-19.sofa
# outputs_16k/sofa/dEchorate_room000000_src2_arr4_mics20-24.sofa
# outputs_16k/sofa/dEchorate_room000010_src3_arr4_mics20-24.sofa
# outputs_16k/sofa/dEchorate_room011000_src1_arr2_mics10-14.sofa
# outputs_16k/sofa/dEchorate_room011000_src1_arr1_mics5-9.sofa
# outputs_16k/sofa/dEchorate_room000100_src4_arr4_mics20-24.sofa
# outputs_16k/sofa/dEchorate_room001000_src0_arr3_mics15-19.sofa
# ...

# %%
# pick one randomly
file = sofa_files[12]

data_ir, source_coordinates, receiver_coordinates = pyfar.io.read_sofa(
    str(file))
print(data_ir)
# Out:
# SOFA file contained custom entries
# ----------------------------------
# ReflectiveSurfacesCode, ReflectiveSurfacesCode_Order, RoomFloorIsRefective, RoomCleilingIsRefective, RoomWestIsRefective, RoomSouthIsRefective, RoomEastIsRefective, RoomNorthIsRefective, RoomHasFornitures, Temperature, Temperature_Units, RelativeHumidity, RelativeHumidity_Units, SpeedOfSound, SpeedOfSound_Units, EchoTimings, EchoTimings_Units, EchoWall, EchoWall_Units
# time domain energy Signal:
# (1, 5) channels with 48000 samples @ 48000.0 Hz sampling rate and none FFT normalization

# %%
pyfar.plot.time_freq(data_ir[0,1])
plt.show()
