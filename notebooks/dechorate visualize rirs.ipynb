# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load RIRs

# %%
path_to_rirs = os.path.join('..', 'data', 'final', 'rir_matrix.npy')
rirs = np.load(path_to_rirs)

print(rirs.shape)
# Out:
# (11, 30, 7, 384000)

# %% [markdown]
# # Visualize RIRs

# %%
curr_rirs = rirs[:, 0, 0, 4444:8000]
C, L = curr_rirs.shape

plt.plot(np.abs(curr_rirs[0, :]))
plt.show()

# %%
plt.imshow(np.abs(curr_rirs).T, aspect='auto')
