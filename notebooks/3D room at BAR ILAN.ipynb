# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pyroomacoustics as pra

# %%
from src import constants

# %%
Rx = constants['room_size'][0]
Ry = constants['room_size'][1]
Rz = constants['room_size'][2]

print(Rx, Ry, Rz)
# Out:
# 5.741 5.763 2.353

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot([0, Rx], [0, 0], [0, 0])
ax.plot([0, 0], [0, Ry] ,[0, 0])
ax.plot([0, 0], [0, 0], [0, Rz])

# %%
corners = np.array([[0, 0, 0.1],
    [180, 0, 0.1],
    [180, 0, 0],
    [376.5, 0, 0],
    [376.5, 0, 0.1],
    [556.5, 0, 0.1],
    [556.5, 568, 0.1],
    [376.5, 568, 0.1],
    [376.5, 568, 0],
    [180, 568, 0],
    [180, 568, 0.1],
    [0, 568, 0.1],
    [0, 0, 2.395],
    [556.5, 0, 2.395],
    [556.5, 568, 2.395],
    [0, 568, 2.395]]).T
corners
# Out:
# array([[0.000e+00, 1.800e+02, 1.800e+02, 3.765e+02, 3.765e+02, 5.565e+02,
#         5.565e+02, 3.765e+02, 3.765e+02, 1.800e+02, 1.800e+02, 0.000e+00,
#         0.000e+00, 5.565e+02, 5.565e+02, 0.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         5.680e+02, 5.680e+02, 5.680e+02, 5.680e+02, 5.680e+02, 5.680e+02,
#         0.000e+00, 0.000e+00, 5.680e+02, 5.680e+02],
#        [1.000e-01, 1.000e-01, 0.000e+00, 0.000e+00, 1.000e-01, 1.000e-01,
#         1.000e-01, 1.000e-01, 0.000e+00, 0.000e+00, 1.000e-01, 1.000e-01,
#         2.395e+00, 2.395e+00, 2.395e+00, 2.395e+00]])

# %%
walls = []
nwalls = 10

for w in range(nwalls):
    walls.append(
        pra.wall_factory(plane.vertices / size_reduc_factor))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-57f2a3802c10> in <module>
#       4 for w in range(nwalls):
#       5     walls.append(
# ----> 6         pra.wall_factory(plane.vertices / size_reduc_factor))
#
# AttributeError: module 'pyroomacoustics' has no attribute 'wall_factory'

# %%
room = pra.Room(
    walls,
    fs=16000,
    max_order=3,
    ray_tracing=True,
    air_absorption=True,
)
